# %%
# 训练五子棋AI

from __future__ import print_function
import random
import numpy as np
# deque 是一个双端队列
from collections import defaultdict, deque
from game import Board, Game
from mcts_pure import MCTSPlayer as MCTS_Pure # 随机走子策略的AI
from mcts_alphaZero import MCTSPlayer # AlphaGo方式的AI
from policy_value_net_pytorch import PolicyValueNet  # Pytorch

class TrainPipeline():
    def __init__(self, init_model=None):
        # 设置棋盘和游戏的参数
        self.board_width = 6
        self.board_height = 6
        self.n_in_row = 4
        self.board = Board(width=self.board_width,
                           height=self.board_height,
                           n_in_row=self.n_in_row)
        self.game = Game(self.board)
        # 设置训练参数
        self.learn_rate = 2e-3 # 基准学习率
        self.lr_multiplier = 1.0  # 基于KL自动调整学习倍速
        self.temp = 1.0  # 温度参数
        self.n_playout = 400  # 每下一步棋，模拟的步骤数
        self.c_puct = 5 # exploitation和exploration之间的折中系数
        self.buffer_size = 10000
        self.batch_size = 512  # mini-batch size for training
        self.data_buffer = deque(maxlen=self.buffer_size) #使用 deque 创建一个双端队列
        self.play_batch_size = 1
        self.epochs = 5  # num of train_steps for each update
        self.kl_targ = 0.02 # 早停检查
        self.check_freq = 50 # 每50次检查一次，策略价值网络是否更新
        self.game_batch_num = 500 # 训练多少个epoch
        self.best_win_ratio = 0.0 # 当前最佳胜率，用他来判断是否有更好的模型
        # 弱AI（纯MCTS）模拟步数，用于给训练的策略AI提供对手
        self.pure_mcts_playout_num = 1000
        if init_model:
            # 通过init_model设置策略网络
            self.policy_value_net = PolicyValueNet(self.board_width, self.board_height, model_file=init_model)
        else:
            # 训练一个新的策略网络
            self.policy_value_net = PolicyValueNet(self.board_width, self.board_height)
        # AI Player，设置is_selfplay=1 自我对弈，因为是在进行训练
        self.mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                      c_puct=self.c_puct,
                                      n_playout=self.n_playout,
                                      is_selfplay=1)
        
    # 通过旋转和翻转增加数据集, play_data: [(state, mcts_prob, winner_z), ..., ...]
    def get_equi_data(self, play_data):
        extend_data = []
        for state, mcts_porb, winner in play_data:
            # 在4个方向上进行expand，每个方向都进行旋转，水平翻转
            for i in [1, 2, 3, 4]:
                # 逆时针旋转
                equi_state = np.array([np.rot90(s, i) for s in state])
                equi_mcts_prob = np.rot90(np.flipud(mcts_porb.reshape(self.board_height, self.board_width)), i)
                extend_data.append((equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
                # 水平翻转
                equi_state = np.array([np.fliplr(s) for s in equi_state])
                equi_mcts_prob = np.fliplr(equi_mcts_prob)
                extend_data.append((equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
        return extend_data

    # 收集自我对弈数据，用于训练
    def collect_selfplay_data(self, n_games=1):
        for i in range(n_games):
            # 与MCTS Player进行对弈
            winner, play_data = self.game.start_self_play(self.mcts_player, temp=self.temp)
            play_data = list(play_data)[:]
            # 保存下了多少步
            self.episode_len = len(play_data)
            # 增加数据 play_data
            play_data = self.get_equi_data(play_data)
            self.data_buffer.extend(play_data)
            
    # 更新策略网络
    def policy_update(self):
        mini_batch = random.sample(self.data_buffer, self.batch_size)
        state_batch = [data[0] for data in mini_batch]
        mcts_probs_batch = [data[1] for data in mini_batch]
        winner_batch = [data[2] for data in mini_batch]
        # 保存更新前的old_probs, old_v
        old_probs, old_v = self.policy_value_net.policy_value(state_batch)
        for i in range(self.epochs):
            # 每次训练，调整参数，返回loss和entropy
            loss, entropy = self.policy_value_net.train_step(
                    state_batch,
                    mcts_probs_batch,
                    winner_batch,
                    self.learn_rate*self.lr_multiplier)
            # 输入状态，得到行动的可能性和状态值，按照batch进行输入
            new_probs, new_v = self.policy_value_net.policy_value(state_batch)
            # 计算更新前后两次的loss差
            kl = np.mean(np.sum(old_probs * (
                    np.log(old_probs + 1e-10) - np.log(new_probs + 1e-10)),
                    axis=1)
            )
            if kl > self.kl_targ * 4:  # early stopping if D_KL diverges badly
                break
        # 动态调整学习倍率 lr_multiplier
        if kl > self.kl_targ * 2 and self.lr_multiplier > 0.1:
            self.lr_multiplier /= 1.5
        elif kl < self.kl_targ / 2 and self.lr_multiplier < 10:
            self.lr_multiplier *= 1.5

        explained_var_old = (1 -
                             np.var(np.array(winner_batch) - old_v.flatten()) /
                             np.var(np.array(winner_batch)))
        explained_var_new = (1 -
                             np.var(np.array(winner_batch) - new_v.flatten()) /
                             np.var(np.array(winner_batch)))
        print(("kl:{:.5f},"
               "lr_multiplier:{:.3f},"
               "loss:{},"
               "entropy:{},"
               "explained_var_old:{:.3f},"
               "explained_var_new:{:.3f}"
               ).format(kl,
                        self.lr_multiplier,
                        loss,
                        entropy,
                        explained_var_old,
                        explained_var_new))
        return loss, entropy

    # 用于评估训练网络的质量，评估一共10场play，返回比赛胜率（赢1分、输0分、平0.5分）
    def policy_evaluate(self, n_games=10):
        current_mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                         c_puct=self.c_puct, n_playout=self.n_playout)
        pure_mcts_player = MCTS_Pure(c_puct=5, n_playout=self.pure_mcts_playout_num)
        win_cnt = defaultdict(int)
        for i in range(n_games):
            # AI和弱AI（纯MCTS）对弈，不需要可视化 is_shown=0，双方轮流职黑 start_player=i % 2
            winner = self.game.start_play(current_mcts_player, pure_mcts_player, start_player=i % 2, is_shown=0)
            win_cnt[winner] += 1
        # 计算胜率，平手计为0.5分
        win_ratio = 1.0*(win_cnt[1] + 0.5*win_cnt[-1]) / n_games
        print("num_playouts:{}, win: {}, lose: {}, tie:{}".format(
                self.pure_mcts_playout_num,
                win_cnt[1], win_cnt[2], win_cnt[-1]))
        return win_ratio

    def run(self):
        # 开始训练
        try:
            # 训练game_batch_num次，每个batch比赛play_batch_size场
            for i in range(self.game_batch_num):
                # 收集自我对弈数据
                self.collect_selfplay_data(self.play_batch_size)
                print("batch i:{}, episode_len:{}".format(i+1, self.episode_len))
                if len(self.data_buffer) > self.batch_size:
                    loss, entropy = self.policy_update()
                # 判断当前模型的表现，保存最优模型
                if (i+1) % self.check_freq == 0:
                    print("current self-play batch: {}".format(i+1))
                    win_ratio = self.policy_evaluate()
                    # 保存当前策略
                    self.policy_value_net.save_model('./current_policy.model')
                    if win_ratio > self.best_win_ratio:
                        print("发现新的最优策略，进行策略更新")
                        self.best_win_ratio = win_ratio
                        # 更新最优策略
                        self.policy_value_net.save_model('./best_policy.model')
                        if (self.best_win_ratio == 1.0 and
                                self.pure_mcts_playout_num < 5000):
                            self.pure_mcts_playout_num += 1000
                            self.best_win_ratio = 0.0
        except KeyboardInterrupt:
            print('\n\rquit')


if __name__ == '__main__':
    training_pipeline = TrainPipeline()
    training_pipeline.run()
# Out:
# C:\Users\Dracula\Untitled Folder 1\policy_value_net_pytorch.py:45: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x_act = F.log_softmax(self.act_fc1(x_act))
# D:\python\lib\site-packages\torch\nn\functional.py:1614: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# batch i:1, episode_len:16
# batch i:2, episode_len:13
# batch i:3, episode_len:16
# batch i:4, episode_len:9
# batch i:5, episode_len:13
# kl:0.00837,lr_multiplier:1.500,loss:4.569027900695801,entropy:3.574512004852295,explained_var_old:0.000,explained_var_new:0.010
# batch i:6, episode_len:11
# kl:0.00517,lr_multiplier:2.250,loss:4.463287353515625,entropy:3.5658254623413086,explained_var_old:0.009,explained_var_new:0.160
# batch i:7, episode_len:20
# kl:0.01638,lr_multiplier:2.250,loss:3.8992257118225098,entropy:3.58003306388855,explained_var_old:0.117,explained_var_new:0.731
# batch i:8, episode_len:14
# kl:0.03151,lr_multiplier:2.250,loss:3.738576650619507,entropy:3.5634446144104004,explained_var_old:0.712,explained_var_new:0.817
# batch i:9, episode_len:16
# kl:0.03283,lr_multiplier:2.250,loss:3.7645103931427,entropy:3.513538122177124,explained_var_old:0.645,explained_var_new:0.740
# batch i:10, episode_len:9
# kl:0.07023,lr_multiplier:1.500,loss:3.801973819732666,entropy:3.4803783893585205,explained_var_old:0.556,explained_var_new:0.658
# batch i:11, episode_len:9
# kl:0.02159,lr_multiplier:1.500,loss:3.711515188217163,entropy:3.409172773361206,explained_var_old:0.615,explained_var_new:0.727
# batch i:12, episode_len:16
# kl:0.02991,lr_multiplier:1.500,loss:3.7386462688446045,entropy:3.445899248123169,explained_var_old:0.542,explained_var_new:0.684
# batch i:13, episode_len:17
# kl:0.02513,lr_multiplier:1.500,loss:3.9340157508850098,entropy:3.4405457973480225,explained_var_old:0.384,explained_var_new:0.479
# batch i:14, episode_len:13
# kl:0.05094,lr_multiplier:1.000,loss:3.8763184547424316,entropy:3.3745710849761963,explained_var_old:0.392,explained_var_new:0.484
# batch i:15, episode_len:16
# kl:0.02741,lr_multiplier:1.000,loss:3.783998966217041,entropy:3.364166259765625,explained_var_old:0.507,explained_var_new:0.571
# batch i:16, episode_len:16
# kl:0.03810,lr_multiplier:1.000,loss:3.9012093544006348,entropy:3.4043219089508057,explained_var_old:0.372,explained_var_new:0.482
# batch i:17, episode_len:18
# kl:0.02949,lr_multiplier:1.000,loss:3.836808919906616,entropy:3.3398940563201904,explained_var_old:0.414,explained_var_new:0.511
# batch i:18, episode_len:9
# kl:0.02714,lr_multiplier:1.000,loss:3.8079402446746826,entropy:3.298159122467041,explained_var_old:0.404,explained_var_new:0.485
# batch i:19, episode_len:9
# kl:0.02553,lr_multiplier:1.000,loss:3.831125259399414,entropy:3.2956020832061768,explained_var_old:0.362,explained_var_new:0.454
# batch i:20, episode_len:19
# kl:0.03799,lr_multiplier:1.000,loss:3.8911736011505127,entropy:3.238358974456787,explained_var_old:0.251,explained_var_new:0.325
# batch i:21, episode_len:12
# kl:0.03152,lr_multiplier:1.000,loss:3.8884551525115967,entropy:3.2504966259002686,explained_var_old:0.261,explained_var_new:0.326
# batch i:22, episode_len:14
# kl:0.03482,lr_multiplier:1.000,loss:3.8363537788391113,entropy:3.228771686553955,explained_var_old:0.274,explained_var_new:0.366
# batch i:23, episode_len:18
# kl:0.03746,lr_multiplier:1.000,loss:3.7983016967773438,entropy:3.1225039958953857,explained_var_old:0.259,explained_var_new:0.326
# batch i:24, episode_len:11
# kl:0.04241,lr_multiplier:0.667,loss:3.789720058441162,entropy:3.148228168487549,explained_var_old:0.240,explained_var_new:0.314
# batch i:25, episode_len:15
# kl:0.02961,lr_multiplier:0.667,loss:3.687034845352173,entropy:3.060582399368286,explained_var_old:0.301,explained_var_new:0.362
# batch i:26, episode_len:9
# kl:0.02469,lr_multiplier:0.667,loss:3.7982656955718994,entropy:3.1089601516723633,explained_var_old:0.220,explained_var_new:0.293
# batch i:27, episode_len:10
# kl:0.03097,lr_multiplier:0.667,loss:3.7638418674468994,entropy:3.0762007236480713,explained_var_old:0.210,explained_var_new:0.267
# batch i:28, episode_len:12
# kl:0.03231,lr_multiplier:0.667,loss:3.6703765392303467,entropy:2.987978935241699,explained_var_old:0.272,explained_var_new:0.347
# batch i:29, episode_len:12
# kl:0.02233,lr_multiplier:0.667,loss:3.59287166595459,entropy:3.0277373790740967,explained_var_old:0.351,explained_var_new:0.398
# batch i:30, episode_len:16
# kl:0.02948,lr_multiplier:0.667,loss:3.6698145866394043,entropy:3.0361692905426025,explained_var_old:0.284,explained_var_new:0.334
# batch i:31, episode_len:9
# kl:0.02351,lr_multiplier:0.667,loss:3.720714569091797,entropy:2.9804959297180176,explained_var_old:0.185,explained_var_new:0.258
# batch i:32, episode_len:16
# kl:0.02119,lr_multiplier:0.667,loss:3.65580677986145,entropy:2.9937474727630615,explained_var_old:0.252,explained_var_new:0.330
# batch i:33, episode_len:9
# kl:0.02308,lr_multiplier:0.667,loss:3.628901243209839,entropy:2.9932961463928223,explained_var_old:0.292,explained_var_new:0.364
# batch i:34, episode_len:7
# kl:0.01962,lr_multiplier:0.667,loss:3.660140037536621,entropy:2.9607491493225098,explained_var_old:0.221,explained_var_new:0.301
# batch i:35, episode_len:12
# kl:0.01940,lr_multiplier:0.667,loss:3.5931224822998047,entropy:2.9628400802612305,explained_var_old:0.265,explained_var_new:0.335
# batch i:36, episode_len:26
# kl:0.03046,lr_multiplier:0.667,loss:3.5104401111602783,entropy:2.8663902282714844,explained_var_old:0.283,explained_var_new:0.372
# batch i:37, episode_len:9
# kl:0.05709,lr_multiplier:0.444,loss:3.6255099773406982,entropy:2.9944918155670166,explained_var_old:0.268,explained_var_new:0.369
# batch i:38, episode_len:17
# kl:0.02044,lr_multiplier:0.444,loss:3.700939655303955,entropy:2.997919797897339,explained_var_old:0.230,explained_var_new:0.287
# batch i:39, episode_len:10
# kl:0.03085,lr_multiplier:0.444,loss:3.603242874145508,entropy:2.9573521614074707,explained_var_old:0.263,explained_var_new:0.343
# batch i:40, episode_len:15
# kl:0.02934,lr_multiplier:0.444,loss:3.623323917388916,entropy:2.935112476348877,explained_var_old:0.286,explained_var_new:0.349
# batch i:41, episode_len:10
# kl:0.02696,lr_multiplier:0.444,loss:3.6204380989074707,entropy:3.0043187141418457,explained_var_old:0.251,explained_var_new:0.328
# batch i:42, episode_len:16
# kl:0.02245,lr_multiplier:0.444,loss:3.4821929931640625,entropy:2.8896660804748535,explained_var_old:0.347,explained_var_new:0.423
# batch i:43, episode_len:18
# kl:0.01467,lr_multiplier:0.444,loss:3.5653982162475586,entropy:2.940373420715332,explained_var_old:0.306,explained_var_new:0.388
# batch i:44, episode_len:13
# kl:0.03215,lr_multiplier:0.444,loss:3.504314661026001,entropy:2.926276445388794,explained_var_old:0.315,explained_var_new:0.399
# batch i:45, episode_len:19
# kl:0.03566,lr_multiplier:0.444,loss:3.5686025619506836,entropy:2.8680710792541504,explained_var_old:0.287,explained_var_new:0.358
# batch i:46, episode_len:16
# kl:0.02586,lr_multiplier:0.444,loss:3.5364160537719727,entropy:2.939002752304077,explained_var_old:0.303,explained_var_new:0.374
# batch i:47, episode_len:11
# kl:0.02019,lr_multiplier:0.444,loss:3.467881917953491,entropy:2.8727707862854004,explained_var_old:0.327,explained_var_new:0.395
# batch i:48, episode_len:14
# kl:0.02216,lr_multiplier:0.444,loss:3.4773502349853516,entropy:2.902336597442627,explained_var_old:0.364,explained_var_new:0.445
# batch i:49, episode_len:10
# kl:0.01942,lr_multiplier:0.444,loss:3.4646401405334473,entropy:2.9588980674743652,explained_var_old:0.410,explained_var_new:0.479
# batch i:50, episode_len:11
# kl:0.04201,lr_multiplier:0.296,loss:3.4062042236328125,entropy:2.9128448963165283,explained_var_old:0.407,explained_var_new:0.483
# current self-play batch: 50
# num_playouts:1000, win: 0, lose: 10, tie:0
# batch i:51, episode_len:20
# kl:0.01479,lr_multiplier:0.296,loss:3.416395664215088,entropy:2.839818000793457,explained_var_old:0.398,explained_var_new:0.472
# batch i:52, episode_len:14
# kl:0.02545,lr_multiplier:0.296,loss:3.403684616088867,entropy:2.8689370155334473,explained_var_old:0.417,explained_var_new:0.471
# batch i:53, episode_len:12
# kl:0.02915,lr_multiplier:0.296,loss:3.3857386112213135,entropy:2.9218475818634033,explained_var_old:0.400,explained_var_new:0.468
# batch i:54, episode_len:11
# kl:0.01843,lr_multiplier:0.296,loss:3.330042600631714,entropy:2.819016933441162,explained_var_old:0.467,explained_var_new:0.516
# batch i:55, episode_len:13
# kl:0.02294,lr_multiplier:0.296,loss:3.3729000091552734,entropy:2.897291421890259,explained_var_old:0.423,explained_var_new:0.488
# batch i:56, episode_len:11
# kl:0.01489,lr_multiplier:0.296,loss:3.4429798126220703,entropy:2.860381603240967,explained_var_old:0.385,explained_var_new:0.448
# batch i:57, episode_len:13
# kl:0.02573,lr_multiplier:0.296,loss:3.3254921436309814,entropy:2.860454797744751,explained_var_old:0.435,explained_var_new:0.507
# batch i:58, episode_len:15
# kl:0.01505,lr_multiplier:0.296,loss:3.393432855606079,entropy:2.8720874786376953,explained_var_old:0.407,explained_var_new:0.496
# batch i:59, episode_len:9
# kl:0.02153,lr_multiplier:0.296,loss:3.379958391189575,entropy:2.898717164993286,explained_var_old:0.444,explained_var_new:0.490
# batch i:60, episode_len:11
# kl:0.01710,lr_multiplier:0.296,loss:3.384429454803467,entropy:2.9179115295410156,explained_var_old:0.433,explained_var_new:0.500
# batch i:61, episode_len:17
# kl:0.01688,lr_multiplier:0.296,loss:3.3567094802856445,entropy:2.871095657348633,explained_var_old:0.446,explained_var_new:0.523
# batch i:62, episode_len:9
# kl:0.01184,lr_multiplier:0.296,loss:3.343198776245117,entropy:2.8869714736938477,explained_var_old:0.480,explained_var_new:0.539
# batch i:63, episode_len:8
# kl:0.02226,lr_multiplier:0.296,loss:3.2652809619903564,entropy:2.805532932281494,explained_var_old:0.488,explained_var_new:0.551
# batch i:64, episode_len:11
# kl:0.01626,lr_multiplier:0.296,loss:3.4037225246429443,entropy:2.9056191444396973,explained_var_old:0.379,explained_var_new:0.478
# batch i:65, episode_len:7
# kl:0.00992,lr_multiplier:0.444,loss:3.303795099258423,entropy:2.8477022647857666,explained_var_old:0.470,explained_var_new:0.526
# batch i:66, episode_len:9
# kl:0.02497,lr_multiplier:0.444,loss:3.3412508964538574,entropy:2.8393635749816895,explained_var_old:0.399,explained_var_new:0.482
# batch i:67, episode_len:10
# kl:0.01962,lr_multiplier:0.444,loss:3.3332903385162354,entropy:2.8015270233154297,explained_var_old:0.410,explained_var_new:0.498
# batch i:68, episode_len:13
# kl:0.02987,lr_multiplier:0.444,loss:3.3143742084503174,entropy:2.818932294845581,explained_var_old:0.421,explained_var_new:0.522
# batch i:69, episode_len:13
# kl:0.02256,lr_multiplier:0.444,loss:3.2666568756103516,entropy:2.8615922927856445,explained_var_old:0.479,explained_var_new:0.562
# batch i:70, episode_len:8
# kl:0.02403,lr_multiplier:0.444,loss:3.268369197845459,entropy:2.8179306983947754,explained_var_old:0.408,explained_var_new:0.530
# batch i:71, episode_len:9
# kl:0.01452,lr_multiplier:0.444,loss:3.3710274696350098,entropy:2.8574185371398926,explained_var_old:0.382,explained_var_new:0.492
# batch i:72, episode_len:14
# kl:0.01634,lr_multiplier:0.444,loss:3.404479503631592,entropy:2.8875625133514404,explained_var_old:0.391,explained_var_new:0.489
# batch i:73, episode_len:8
# kl:0.01591,lr_multiplier:0.444,loss:3.2928872108459473,entropy:2.857914924621582,explained_var_old:0.403,explained_var_new:0.514
# batch i:74, episode_len:11
# kl:0.02920,lr_multiplier:0.444,loss:3.3166027069091797,entropy:2.7743821144104004,explained_var_old:0.451,explained_var_new:0.531
# batch i:75, episode_len:7
# kl:0.03743,lr_multiplier:0.444,loss:3.3714919090270996,entropy:2.916163444519043,explained_var_old:0.385,explained_var_new:0.503
# batch i:76, episode_len:12
# kl:0.04076,lr_multiplier:0.296,loss:3.331064224243164,entropy:2.810316801071167,explained_var_old:0.450,explained_var_new:0.525
# batch i:77, episode_len:18
# kl:0.02672,lr_multiplier:0.296,loss:3.3288960456848145,entropy:2.908900499343872,explained_var_old:0.422,explained_var_new:0.531
# batch i:78, episode_len:13
# kl:0.02418,lr_multiplier:0.296,loss:3.385681629180908,entropy:2.8342018127441406,explained_var_old:0.362,explained_var_new:0.456
# batch i:79, episode_len:9
# kl:0.01533,lr_multiplier:0.296,loss:3.4485156536102295,entropy:2.8216795921325684,explained_var_old:0.290,explained_var_new:0.392
# batch i:80, episode_len:15
# kl:0.00900,lr_multiplier:0.444,loss:3.3703150749206543,entropy:2.834656238555908,explained_var_old:0.352,explained_var_new:0.443
# batch i:81, episode_len:11
# kl:0.02663,lr_multiplier:0.444,loss:3.350048542022705,entropy:2.8486883640289307,explained_var_old:0.411,explained_var_new:0.497
# batch i:82, episode_len:9
# kl:0.02199,lr_multiplier:0.444,loss:3.3729872703552246,entropy:2.864386796951294,explained_var_old:0.360,explained_var_new:0.468
# batch i:83, episode_len:9
# kl:0.02172,lr_multiplier:0.444,loss:3.3106837272644043,entropy:2.8450396060943604,explained_var_old:0.427,explained_var_new:0.506
# batch i:84, episode_len:13
# kl:0.02292,lr_multiplier:0.444,loss:3.3252923488616943,entropy:2.8020102977752686,explained_var_old:0.392,explained_var_new:0.492
# batch i:85, episode_len:7
# kl:0.02244,lr_multiplier:0.444,loss:3.3339836597442627,entropy:2.845522880554199,explained_var_old:0.367,explained_var_new:0.459
# batch i:86, episode_len:13
# kl:0.04235,lr_multiplier:0.296,loss:3.2680225372314453,entropy:2.741630792617798,explained_var_old:0.395,explained_var_new:0.509
# batch i:87, episode_len:13
# kl:0.03346,lr_multiplier:0.296,loss:3.2577829360961914,entropy:2.839059829711914,explained_var_old:0.479,explained_var_new:0.542
# batch i:88, episode_len:11
# kl:0.03239,lr_multiplier:0.296,loss:3.2823128700256348,entropy:2.7437682151794434,explained_var_old:0.430,explained_var_new:0.503
# batch i:89, episode_len:13
# kl:0.01790,lr_multiplier:0.296,loss:3.267827272415161,entropy:2.7545559406280518,explained_var_old:0.391,explained_var_new:0.477
# batch i:90, episode_len:10
# kl:0.01316,lr_multiplier:0.296,loss:3.2371268272399902,entropy:2.827364921569824,explained_var_old:0.481,explained_var_new:0.532
# batch i:91, episode_len:11
# kl:0.01752,lr_multiplier:0.296,loss:3.1880457401275635,entropy:2.7206647396087646,explained_var_old:0.459,explained_var_new:0.515
# batch i:92, episode_len:7
# kl:0.01607,lr_multiplier:0.296,loss:3.279564380645752,entropy:2.7893290519714355,explained_var_old:0.438,explained_var_new:0.516
# batch i:93, episode_len:11
# kl:0.01187,lr_multiplier:0.296,loss:3.200493335723877,entropy:2.792829751968384,explained_var_old:0.521,explained_var_new:0.591
# batch i:94, episode_len:14
# kl:0.01493,lr_multiplier:0.296,loss:3.193422555923462,entropy:2.7291407585144043,explained_var_old:0.445,explained_var_new:0.532
# batch i:95, episode_len:18
# kl:0.01601,lr_multiplier:0.296,loss:3.182690143585205,entropy:2.736388683319092,explained_var_old:0.491,explained_var_new:0.541
# batch i:96, episode_len:19
# kl:0.01331,lr_multiplier:0.296,loss:3.2819058895111084,entropy:2.7210280895233154,explained_var_old:0.377,explained_var_new:0.472
# batch i:97, episode_len:19
# kl:0.01238,lr_multiplier:0.296,loss:3.2776832580566406,entropy:2.7731804847717285,explained_var_old:0.430,explained_var_new:0.492
# batch i:98, episode_len:12
# kl:0.01410,lr_multiplier:0.296,loss:3.316560983657837,entropy:2.7691686153411865,explained_var_old:0.343,explained_var_new:0.413
# batch i:99, episode_len:7
# kl:0.01340,lr_multiplier:0.296,loss:3.252389907836914,entropy:2.7466881275177,explained_var_old:0.379,explained_var_new:0.461
# batch i:100, episode_len:14
# kl:0.01496,lr_multiplier:0.296,loss:3.2749462127685547,entropy:2.7337746620178223,explained_var_old:0.392,explained_var_new:0.464
# current self-play batch: 100
# num_playouts:1000, win: 6, lose: 4, tie:0
# 发现新的最优策略，进行策略更新
# batch i:101, episode_len:11
# kl:0.02120,lr_multiplier:0.296,loss:3.354541540145874,entropy:2.7590041160583496,explained_var_old:0.360,explained_var_new:0.432
# batch i:102, episode_len:19
# kl:0.01260,lr_multiplier:0.296,loss:3.2874679565429688,entropy:2.789543867111206,explained_var_old:0.360,explained_var_new:0.459
# batch i:103, episode_len:12
# kl:0.01471,lr_multiplier:0.296,loss:3.2970266342163086,entropy:2.745840549468994,explained_var_old:0.316,explained_var_new:0.393
# batch i:104, episode_len:16
# kl:0.01277,lr_multiplier:0.296,loss:3.3081002235412598,entropy:2.7017457485198975,explained_var_old:0.319,explained_var_new:0.413
# batch i:105, episode_len:15
# kl:0.01659,lr_multiplier:0.296,loss:3.2692818641662598,entropy:2.6852118968963623,explained_var_old:0.348,explained_var_new:0.404
# batch i:106, episode_len:10
# kl:0.01026,lr_multiplier:0.296,loss:3.2416977882385254,entropy:2.688345193862915,explained_var_old:0.390,explained_var_new:0.462
# batch i:107, episode_len:8
# kl:0.02081,lr_multiplier:0.296,loss:3.197540283203125,entropy:2.6476247310638428,explained_var_old:0.368,explained_var_new:0.455
# batch i:108, episode_len:11
# kl:0.01830,lr_multiplier:0.296,loss:3.2801766395568848,entropy:2.714512348175049,explained_var_old:0.349,explained_var_new:0.405
# batch i:109, episode_len:11
# kl:0.01714,lr_multiplier:0.296,loss:3.258305311203003,entropy:2.6420280933380127,explained_var_old:0.313,explained_var_new:0.393
# batch i:110, episode_len:9
# kl:0.02256,lr_multiplier:0.296,loss:3.2752175331115723,entropy:2.7378740310668945,explained_var_old:0.387,explained_var_new:0.453
# batch i:111, episode_len:7
# kl:0.02137,lr_multiplier:0.296,loss:3.288073778152466,entropy:2.7057204246520996,explained_var_old:0.344,explained_var_new:0.417
# batch i:112, episode_len:17
# kl:0.01943,lr_multiplier:0.296,loss:3.177194356918335,entropy:2.679326295852661,explained_var_old:0.399,explained_var_new:0.470
# batch i:113, episode_len:7
# kl:0.01743,lr_multiplier:0.296,loss:3.2704668045043945,entropy:2.6680240631103516,explained_var_old:0.331,explained_var_new:0.391
# batch i:114, episode_len:9
# kl:0.01635,lr_multiplier:0.296,loss:3.1950855255126953,entropy:2.6122708320617676,explained_var_old:0.353,explained_var_new:0.416
# batch i:115, episode_len:7
# kl:0.02239,lr_multiplier:0.296,loss:3.1578869819641113,entropy:2.699739694595337,explained_var_old:0.414,explained_var_new:0.477
# batch i:116, episode_len:7
# kl:0.02069,lr_multiplier:0.296,loss:3.161416530609131,entropy:2.614487409591675,explained_var_old:0.364,explained_var_new:0.428
# batch i:117, episode_len:7
# kl:0.02092,lr_multiplier:0.296,loss:3.161470413208008,entropy:2.622000217437744,explained_var_old:0.371,explained_var_new:0.452
# batch i:118, episode_len:13
# kl:0.01457,lr_multiplier:0.296,loss:3.1318042278289795,entropy:2.5952460765838623,explained_var_old:0.377,explained_var_new:0.465
# batch i:119, episode_len:9
# kl:0.01156,lr_multiplier:0.296,loss:3.1823887825012207,entropy:2.6474204063415527,explained_var_old:0.393,explained_var_new:0.456
# batch i:120, episode_len:9
# kl:0.01603,lr_multiplier:0.296,loss:3.0330560207366943,entropy:2.55881667137146,explained_var_old:0.438,explained_var_new:0.524
# batch i:121, episode_len:13
# kl:0.01794,lr_multiplier:0.296,loss:3.1375370025634766,entropy:2.6064887046813965,explained_var_old:0.380,explained_var_new:0.446
# batch i:122, episode_len:8
# kl:0.02359,lr_multiplier:0.296,loss:3.0590498447418213,entropy:2.557814836502075,explained_var_old:0.427,explained_var_new:0.491
# batch i:123, episode_len:11
# kl:0.01827,lr_multiplier:0.296,loss:3.0980517864227295,entropy:2.533174514770508,explained_var_old:0.392,explained_var_new:0.456
# batch i:124, episode_len:13
# kl:0.01356,lr_multiplier:0.296,loss:3.0016283988952637,entropy:2.5384035110473633,explained_var_old:0.432,explained_var_new:0.503
# batch i:125, episode_len:13
# kl:0.01207,lr_multiplier:0.296,loss:3.069453477859497,entropy:2.5227293968200684,explained_var_old:0.368,explained_var_new:0.438
# batch i:126, episode_len:7
# kl:0.01174,lr_multiplier:0.296,loss:3.0752546787261963,entropy:2.570141315460205,explained_var_old:0.441,explained_var_new:0.509
# batch i:127, episode_len:7
# kl:0.01210,lr_multiplier:0.296,loss:3.03175687789917,entropy:2.5939011573791504,explained_var_old:0.476,explained_var_new:0.529
# batch i:128, episode_len:9
# kl:0.01221,lr_multiplier:0.296,loss:3.0596067905426025,entropy:2.5635910034179688,explained_var_old:0.405,explained_var_new:0.488
# batch i:129, episode_len:13
# kl:0.01864,lr_multiplier:0.296,loss:3.109830141067505,entropy:2.580007314682007,explained_var_old:0.382,explained_var_new:0.448
# batch i:130, episode_len:7
# kl:0.01661,lr_multiplier:0.296,loss:2.976881742477417,entropy:2.539935350418091,explained_var_old:0.546,explained_var_new:0.604
# batch i:131, episode_len:13
# kl:0.02011,lr_multiplier:0.296,loss:3.1456298828125,entropy:2.56318998336792,explained_var_old:0.357,explained_var_new:0.429
# batch i:132, episode_len:10
# kl:0.01928,lr_multiplier:0.296,loss:3.04653263092041,entropy:2.5263724327087402,explained_var_old:0.421,explained_var_new:0.488
# batch i:133, episode_len:7
# kl:0.01628,lr_multiplier:0.296,loss:3.0552358627319336,entropy:2.5508689880371094,explained_var_old:0.425,explained_var_new:0.468
# batch i:134, episode_len:8
# kl:0.01476,lr_multiplier:0.296,loss:3.0277469158172607,entropy:2.517345428466797,explained_var_old:0.377,explained_var_new:0.450
# batch i:135, episode_len:9
# kl:0.01783,lr_multiplier:0.296,loss:3.104531764984131,entropy:2.54976487159729,explained_var_old:0.388,explained_var_new:0.467
# batch i:136, episode_len:9
# kl:0.01493,lr_multiplier:0.296,loss:3.0119121074676514,entropy:2.5317959785461426,explained_var_old:0.452,explained_var_new:0.505
# batch i:137, episode_len:13
# kl:0.01046,lr_multiplier:0.296,loss:3.0345935821533203,entropy:2.4790456295013428,explained_var_old:0.402,explained_var_new:0.458
# batch i:138, episode_len:12
# kl:0.01629,lr_multiplier:0.296,loss:3.191721200942993,entropy:2.604550838470459,explained_var_old:0.321,explained_var_new:0.402
# batch i:139, episode_len:8
# kl:0.01506,lr_multiplier:0.296,loss:3.0595035552978516,entropy:2.556138038635254,explained_var_old:0.387,explained_var_new:0.454
# batch i:140, episode_len:19
# kl:0.02024,lr_multiplier:0.296,loss:3.0430727005004883,entropy:2.5264482498168945,explained_var_old:0.415,explained_var_new:0.473
# batch i:141, episode_len:7
# kl:0.01836,lr_multiplier:0.296,loss:3.1486434936523438,entropy:2.577091693878174,explained_var_old:0.338,explained_var_new:0.423
# batch i:142, episode_len:9
# kl:0.03125,lr_multiplier:0.296,loss:3.058873176574707,entropy:2.515073776245117,explained_var_old:0.413,explained_var_new:0.473
# batch i:143, episode_len:11
# kl:0.03842,lr_multiplier:0.296,loss:3.049254894256592,entropy:2.5423834323883057,explained_var_old:0.421,explained_var_new:0.478
# batch i:144, episode_len:13
# kl:0.03057,lr_multiplier:0.296,loss:3.1316885948181152,entropy:2.5529422760009766,explained_var_old:0.297,explained_var_new:0.389
# batch i:145, episode_len:13
# kl:0.02165,lr_multiplier:0.296,loss:3.066305160522461,entropy:2.516188859939575,explained_var_old:0.418,explained_var_new:0.474
# batch i:146, episode_len:7
# kl:0.02488,lr_multiplier:0.296,loss:3.0985989570617676,entropy:2.549640655517578,explained_var_old:0.349,explained_var_new:0.421
# batch i:147, episode_len:11
# kl:0.02173,lr_multiplier:0.296,loss:3.031499147415161,entropy:2.5134949684143066,explained_var_old:0.452,explained_var_new:0.508
# batch i:148, episode_len:7
# kl:0.02345,lr_multiplier:0.296,loss:3.02643084526062,entropy:2.53033447265625,explained_var_old:0.412,explained_var_new:0.484
# batch i:149, episode_len:11
# kl:0.02277,lr_multiplier:0.296,loss:3.0679140090942383,entropy:2.4449024200439453,explained_var_old:0.348,explained_var_new:0.402
# batch i:150, episode_len:13
# kl:0.01420,lr_multiplier:0.296,loss:2.9493346214294434,entropy:2.4710724353790283,explained_var_old:0.459,explained_var_new:0.515
# current self-play batch: 150
# num_playouts:1000, win: 7, lose: 3, tie:0
# 发现新的最优策略，进行策略更新
# batch i:151, episode_len:15
# kl:0.01840,lr_multiplier:0.296,loss:2.870661497116089,entropy:2.531259059906006,explained_var_old:0.531,explained_var_new:0.576
# batch i:152, episode_len:12
# kl:0.02512,lr_multiplier:0.296,loss:3.0046749114990234,entropy:2.420194149017334,explained_var_old:0.403,explained_var_new:0.466
# batch i:153, episode_len:13
# kl:0.02525,lr_multiplier:0.296,loss:2.9177448749542236,entropy:2.4964985847473145,explained_var_old:0.474,explained_var_new:0.519
# batch i:154, episode_len:14
# kl:0.02545,lr_multiplier:0.296,loss:2.856435537338257,entropy:2.417268753051758,explained_var_old:0.447,explained_var_new:0.510
# batch i:155, episode_len:7
# kl:0.01641,lr_multiplier:0.296,loss:3.0128395557403564,entropy:2.4266600608825684,explained_var_old:0.388,explained_var_new:0.440
# batch i:156, episode_len:20
# kl:0.02217,lr_multiplier:0.296,loss:2.980949640274048,entropy:2.454108953475952,explained_var_old:0.403,explained_var_new:0.464
# batch i:157, episode_len:7
# kl:0.01195,lr_multiplier:0.296,loss:3.110459089279175,entropy:2.4576661586761475,explained_var_old:0.261,explained_var_new:0.343
# batch i:158, episode_len:10
# kl:0.01573,lr_multiplier:0.296,loss:3.025399684906006,entropy:2.449993371963501,explained_var_old:0.341,explained_var_new:0.393
# batch i:159, episode_len:9
# kl:0.02049,lr_multiplier:0.296,loss:2.999134063720703,entropy:2.387637138366699,explained_var_old:0.347,explained_var_new:0.412
# batch i:160, episode_len:9
# kl:0.00918,lr_multiplier:0.444,loss:2.958428382873535,entropy:2.4280755519866943,explained_var_old:0.392,explained_var_new:0.452
# batch i:161, episode_len:13
# kl:0.02595,lr_multiplier:0.444,loss:2.93707013130188,entropy:2.4047129154205322,explained_var_old:0.382,explained_var_new:0.454
# batch i:162, episode_len:8
# kl:0.03855,lr_multiplier:0.444,loss:2.8654470443725586,entropy:2.315258741378784,explained_var_old:0.385,explained_var_new:0.459
# batch i:163, episode_len:11
# kl:0.04697,lr_multiplier:0.296,loss:2.900712013244629,entropy:2.376889228820801,explained_var_old:0.389,explained_var_new:0.454
# batch i:164, episode_len:7
# kl:0.03022,lr_multiplier:0.296,loss:2.8962457180023193,entropy:2.414734363555908,explained_var_old:0.471,explained_var_new:0.512
# batch i:165, episode_len:9
# kl:0.01435,lr_multiplier:0.296,loss:2.922762393951416,entropy:2.4291696548461914,explained_var_old:0.435,explained_var_new:0.482
# batch i:166, episode_len:19
# kl:0.01773,lr_multiplier:0.296,loss:2.9769248962402344,entropy:2.401153087615967,explained_var_old:0.383,explained_var_new:0.428
# batch i:167, episode_len:12
# kl:0.02183,lr_multiplier:0.296,loss:2.8650195598602295,entropy:2.4161906242370605,explained_var_old:0.458,explained_var_new:0.514
# batch i:168, episode_len:13
# kl:0.02103,lr_multiplier:0.296,loss:2.916794776916504,entropy:2.384692907333374,explained_var_old:0.435,explained_var_new:0.487
# batch i:169, episode_len:9
# kl:0.01273,lr_multiplier:0.296,loss:2.9028942584991455,entropy:2.407222270965576,explained_var_old:0.405,explained_var_new:0.468
# batch i:170, episode_len:7
# kl:0.02168,lr_multiplier:0.296,loss:2.773599624633789,entropy:2.3287668228149414,explained_var_old:0.465,explained_var_new:0.536
# batch i:171, episode_len:17
# kl:0.02137,lr_multiplier:0.296,loss:3.072056770324707,entropy:2.485280752182007,explained_var_old:0.326,explained_var_new:0.404
# batch i:172, episode_len:9
# kl:0.02314,lr_multiplier:0.296,loss:2.926358222961426,entropy:2.3453567028045654,explained_var_old:0.360,explained_var_new:0.419
# batch i:173, episode_len:9
# kl:0.01850,lr_multiplier:0.296,loss:2.8658809661865234,entropy:2.3119912147521973,explained_var_old:0.434,explained_var_new:0.499
# batch i:174, episode_len:7
# kl:0.01409,lr_multiplier:0.296,loss:2.824828624725342,entropy:2.3752353191375732,explained_var_old:0.468,explained_var_new:0.506
# batch i:175, episode_len:12
# kl:0.02191,lr_multiplier:0.296,loss:3.0009548664093018,entropy:2.4039530754089355,explained_var_old:0.380,explained_var_new:0.433
# batch i:176, episode_len:9
# kl:0.02182,lr_multiplier:0.296,loss:2.895235538482666,entropy:2.4365553855895996,explained_var_old:0.396,explained_var_new:0.458
# batch i:177, episode_len:11
# kl:0.02975,lr_multiplier:0.296,loss:2.838473081588745,entropy:2.335865020751953,explained_var_old:0.422,explained_var_new:0.500
# batch i:178, episode_len:11
# kl:0.03745,lr_multiplier:0.296,loss:2.857630491256714,entropy:2.3926262855529785,explained_var_old:0.461,explained_var_new:0.507
# batch i:179, episode_len:13
# kl:0.02620,lr_multiplier:0.296,loss:2.9383535385131836,entropy:2.3959619998931885,explained_var_old:0.386,explained_var_new:0.457
# batch i:180, episode_len:14
# kl:0.01973,lr_multiplier:0.296,loss:2.9441049098968506,entropy:2.4195804595947266,explained_var_old:0.391,explained_var_new:0.449
# batch i:181, episode_len:8
# kl:0.01572,lr_multiplier:0.296,loss:2.866442918777466,entropy:2.3511369228363037,explained_var_old:0.402,explained_var_new:0.469
# batch i:182, episode_len:7
# kl:0.02255,lr_multiplier:0.296,loss:2.882608652114868,entropy:2.313596725463867,explained_var_old:0.367,explained_var_new:0.425
# batch i:183, episode_len:13
# kl:0.01952,lr_multiplier:0.296,loss:2.8807902336120605,entropy:2.402796506881714,explained_var_old:0.418,explained_var_new:0.483
# batch i:184, episode_len:7
# kl:0.03247,lr_multiplier:0.296,loss:2.7556405067443848,entropy:2.2487761974334717,explained_var_old:0.471,explained_var_new:0.527
# batch i:185, episode_len:8
# kl:0.02706,lr_multiplier:0.296,loss:2.8464083671569824,entropy:2.3677978515625,explained_var_old:0.439,explained_var_new:0.496
# batch i:186, episode_len:14
# kl:0.02031,lr_multiplier:0.296,loss:2.7913882732391357,entropy:2.381727457046509,explained_var_old:0.499,explained_var_new:0.553
# batch i:187, episode_len:7
# kl:0.01730,lr_multiplier:0.296,loss:2.8097681999206543,entropy:2.3234736919403076,explained_var_old:0.472,explained_var_new:0.520
# batch i:188, episode_len:10
# kl:0.01672,lr_multiplier:0.296,loss:2.7925305366516113,entropy:2.284693479537964,explained_var_old:0.364,explained_var_new:0.434
# batch i:189, episode_len:9
# kl:0.01562,lr_multiplier:0.296,loss:2.7187657356262207,entropy:2.2773311138153076,explained_var_old:0.515,explained_var_new:0.565
# batch i:190, episode_len:10
# kl:0.01745,lr_multiplier:0.296,loss:2.9330012798309326,entropy:2.3747599124908447,explained_var_old:0.312,explained_var_new:0.383
# batch i:191, episode_len:9
# kl:0.01922,lr_multiplier:0.296,loss:2.8553805351257324,entropy:2.338103771209717,explained_var_old:0.391,explained_var_new:0.459
# batch i:192, episode_len:9
# kl:0.01913,lr_multiplier:0.296,loss:2.705169677734375,entropy:2.245358943939209,explained_var_old:0.471,explained_var_new:0.536
# batch i:193, episode_len:10
# kl:0.02852,lr_multiplier:0.296,loss:2.8581924438476562,entropy:2.3284404277801514,explained_var_old:0.369,explained_var_new:0.435
# batch i:194, episode_len:13
# kl:0.02467,lr_multiplier:0.296,loss:2.846942186355591,entropy:2.3144028186798096,explained_var_old:0.411,explained_var_new:0.474
# batch i:195, episode_len:11
# kl:0.02595,lr_multiplier:0.296,loss:2.7521519660949707,entropy:2.2449567317962646,explained_var_old:0.410,explained_var_new:0.474
# batch i:196, episode_len:7
# kl:0.01699,lr_multiplier:0.296,loss:2.8016676902770996,entropy:2.3083748817443848,explained_var_old:0.440,explained_var_new:0.490
# batch i:197, episode_len:14
# kl:0.02583,lr_multiplier:0.296,loss:2.8448376655578613,entropy:2.3511180877685547,explained_var_old:0.405,explained_var_new:0.455
# batch i:198, episode_len:10
# kl:0.01960,lr_multiplier:0.296,loss:2.785329818725586,entropy:2.2806222438812256,explained_var_old:0.462,explained_var_new:0.529
# batch i:199, episode_len:12
# kl:0.02395,lr_multiplier:0.296,loss:2.8491568565368652,entropy:2.2963922023773193,explained_var_old:0.345,explained_var_new:0.423
# batch i:200, episode_len:7
# kl:0.03018,lr_multiplier:0.296,loss:2.8613054752349854,entropy:2.2674577236175537,explained_var_old:0.342,explained_var_new:0.417
# current self-play batch: 200
# num_playouts:1000, win: 9, lose: 1, tie:0
# 发现新的最优策略，进行策略更新
# batch i:201, episode_len:7
# kl:0.03833,lr_multiplier:0.296,loss:2.923966407775879,entropy:2.353080987930298,explained_var_old:0.297,explained_var_new:0.377
# batch i:202, episode_len:16
# kl:0.04978,lr_multiplier:0.198,loss:2.8322644233703613,entropy:2.2080557346343994,explained_var_old:0.370,explained_var_new:0.423
# batch i:203, episode_len:9
# kl:0.04435,lr_multiplier:0.132,loss:2.7331438064575195,entropy:2.2665319442749023,explained_var_old:0.389,explained_var_new:0.447
# batch i:204, episode_len:12
# kl:0.01663,lr_multiplier:0.132,loss:2.8862881660461426,entropy:2.3273279666900635,explained_var_old:0.369,explained_var_new:0.413
# batch i:205, episode_len:9
# kl:0.00932,lr_multiplier:0.198,loss:2.846079111099243,entropy:2.258485794067383,explained_var_old:0.380,explained_var_new:0.412
# batch i:206, episode_len:10
# kl:0.01506,lr_multiplier:0.198,loss:2.9011173248291016,entropy:2.342709541320801,explained_var_old:0.352,explained_var_new:0.410
# batch i:207, episode_len:7
# kl:0.00745,lr_multiplier:0.296,loss:2.8787362575531006,entropy:2.3038265705108643,explained_var_old:0.331,explained_var_new:0.383
# batch i:208, episode_len:14
# kl:0.02117,lr_multiplier:0.296,loss:2.8020033836364746,entropy:2.2309346199035645,explained_var_old:0.366,explained_var_new:0.445
# batch i:209, episode_len:7
# kl:0.02040,lr_multiplier:0.296,loss:2.8709161281585693,entropy:2.285583972930908,explained_var_old:0.353,explained_var_new:0.426
# batch i:210, episode_len:16
# kl:0.01910,lr_multiplier:0.296,loss:2.7182576656341553,entropy:2.2233548164367676,explained_var_old:0.400,explained_var_new:0.465
# batch i:211, episode_len:8
# kl:0.02096,lr_multiplier:0.296,loss:2.873323917388916,entropy:2.298790216445923,explained_var_old:0.335,explained_var_new:0.401
# batch i:212, episode_len:15
# kl:0.02355,lr_multiplier:0.296,loss:2.804321765899658,entropy:2.231110095977783,explained_var_old:0.372,explained_var_new:0.439
# batch i:213, episode_len:15
# kl:0.01889,lr_multiplier:0.296,loss:2.808680295944214,entropy:2.2624142169952393,explained_var_old:0.364,explained_var_new:0.435
# batch i:214, episode_len:9
# kl:0.02198,lr_multiplier:0.296,loss:2.8187131881713867,entropy:2.1855597496032715,explained_var_old:0.315,explained_var_new:0.387
# batch i:215, episode_len:8
# kl:0.02114,lr_multiplier:0.296,loss:2.8514342308044434,entropy:2.3254010677337646,explained_var_old:0.356,explained_var_new:0.433
# batch i:216, episode_len:8
# kl:0.01475,lr_multiplier:0.296,loss:2.740318775177002,entropy:2.233402967453003,explained_var_old:0.439,explained_var_new:0.502
# batch i:217, episode_len:10
# kl:0.03004,lr_multiplier:0.296,loss:2.828186273574829,entropy:2.316895008087158,explained_var_old:0.386,explained_var_new:0.459
# batch i:218, episode_len:15
# kl:0.03127,lr_multiplier:0.296,loss:2.8898768424987793,entropy:2.215714931488037,explained_var_old:0.276,explained_var_new:0.340
# batch i:219, episode_len:14
# kl:0.02771,lr_multiplier:0.296,loss:2.8268277645111084,entropy:2.2767248153686523,explained_var_old:0.339,explained_var_new:0.442
# batch i:220, episode_len:16
# kl:0.02330,lr_multiplier:0.296,loss:2.8835482597351074,entropy:2.2205569744110107,explained_var_old:0.289,explained_var_new:0.357
# batch i:221, episode_len:16
# kl:0.01682,lr_multiplier:0.296,loss:2.7406489849090576,entropy:2.200915813446045,explained_var_old:0.382,explained_var_new:0.445
# batch i:222, episode_len:10
# kl:0.04248,lr_multiplier:0.198,loss:2.814138650894165,entropy:2.263607978820801,explained_var_old:0.322,explained_var_new:0.398
# batch i:223, episode_len:7
# kl:0.02484,lr_multiplier:0.198,loss:2.7868125438690186,entropy:2.161925792694092,explained_var_old:0.296,explained_var_new:0.364
# batch i:224, episode_len:9
# kl:0.01933,lr_multiplier:0.198,loss:2.8156847953796387,entropy:2.2440083026885986,explained_var_old:0.341,explained_var_new:0.417
# batch i:225, episode_len:13
# kl:0.01951,lr_multiplier:0.198,loss:2.8288683891296387,entropy:2.245466709136963,explained_var_old:0.355,explained_var_new:0.403
# batch i:226, episode_len:10
# kl:0.01743,lr_multiplier:0.198,loss:2.826958179473877,entropy:2.2092196941375732,explained_var_old:0.293,explained_var_new:0.343
# batch i:227, episode_len:12
# kl:0.01654,lr_multiplier:0.198,loss:2.8547322750091553,entropy:2.2054221630096436,explained_var_old:0.283,explained_var_new:0.341
# batch i:228, episode_len:7
# kl:0.01527,lr_multiplier:0.198,loss:2.7494781017303467,entropy:2.198474407196045,explained_var_old:0.357,explained_var_new:0.422
# batch i:229, episode_len:12
# kl:0.01357,lr_multiplier:0.198,loss:2.792508125305176,entropy:2.236464023590088,explained_var_old:0.344,explained_var_new:0.384
# batch i:230, episode_len:20
# kl:0.01927,lr_multiplier:0.198,loss:2.7502551078796387,entropy:2.174288749694824,explained_var_old:0.377,explained_var_new:0.424
# batch i:231, episode_len:10
# kl:0.01288,lr_multiplier:0.198,loss:2.722784996032715,entropy:2.170895576477051,explained_var_old:0.401,explained_var_new:0.454
# batch i:232, episode_len:13
# kl:0.01491,lr_multiplier:0.198,loss:2.8670878410339355,entropy:2.2424540519714355,explained_var_old:0.292,explained_var_new:0.355
# batch i:233, episode_len:10
# kl:0.00903,lr_multiplier:0.296,loss:2.7946534156799316,entropy:2.186633586883545,explained_var_old:0.374,explained_var_new:0.421
# batch i:234, episode_len:10
# kl:0.02446,lr_multiplier:0.296,loss:2.650841474533081,entropy:2.1983909606933594,explained_var_old:0.411,explained_var_new:0.477
# batch i:235, episode_len:7
# kl:0.01787,lr_multiplier:0.296,loss:2.7068116664886475,entropy:2.0955677032470703,explained_var_old:0.339,explained_var_new:0.400
# batch i:236, episode_len:16
# kl:0.01652,lr_multiplier:0.296,loss:2.8826489448547363,entropy:2.230837345123291,explained_var_old:0.236,explained_var_new:0.306
# batch i:237, episode_len:13
# kl:0.02510,lr_multiplier:0.296,loss:2.8512353897094727,entropy:2.168839931488037,explained_var_old:0.223,explained_var_new:0.330
# batch i:238, episode_len:9
# kl:0.01936,lr_multiplier:0.296,loss:2.8102002143859863,entropy:2.1970162391662598,explained_var_old:0.304,explained_var_new:0.367
# batch i:239, episode_len:12
# kl:0.02659,lr_multiplier:0.296,loss:2.7508959770202637,entropy:2.2442543506622314,explained_var_old:0.340,explained_var_new:0.414
# batch i:240, episode_len:9
# kl:0.02696,lr_multiplier:0.296,loss:2.776224136352539,entropy:2.2003672122955322,explained_var_old:0.317,explained_var_new:0.376
# batch i:241, episode_len:9
# kl:0.02303,lr_multiplier:0.296,loss:2.8365933895111084,entropy:2.1998136043548584,explained_var_old:0.287,explained_var_new:0.376
# batch i:242, episode_len:9
# kl:0.01873,lr_multiplier:0.296,loss:2.7946252822875977,entropy:2.1645641326904297,explained_var_old:0.294,explained_var_new:0.352
# batch i:243, episode_len:14
# kl:0.02210,lr_multiplier:0.296,loss:2.687695026397705,entropy:2.1224122047424316,explained_var_old:0.299,explained_var_new:0.369
# batch i:244, episode_len:8
# kl:0.02483,lr_multiplier:0.296,loss:2.732684373855591,entropy:2.125605344772339,explained_var_old:0.337,explained_var_new:0.397
# batch i:245, episode_len:8
# kl:0.02989,lr_multiplier:0.296,loss:2.8145933151245117,entropy:2.15055513381958,explained_var_old:0.249,explained_var_new:0.332
# batch i:246, episode_len:10
# kl:0.02776,lr_multiplier:0.296,loss:2.8127946853637695,entropy:2.144298791885376,explained_var_old:0.219,explained_var_new:0.299
# batch i:247, episode_len:7
# kl:0.02186,lr_multiplier:0.296,loss:2.7113468647003174,entropy:2.143211841583252,explained_var_old:0.322,explained_var_new:0.383
# batch i:248, episode_len:7
# kl:0.03835,lr_multiplier:0.296,loss:2.816798210144043,entropy:2.2126309871673584,explained_var_old:0.285,explained_var_new:0.365
# batch i:249, episode_len:7
# kl:0.01991,lr_multiplier:0.296,loss:2.7346043586730957,entropy:2.180602550506592,explained_var_old:0.318,explained_var_new:0.397
# batch i:250, episode_len:17
# kl:0.02339,lr_multiplier:0.296,loss:2.8903136253356934,entropy:2.1791369915008545,explained_var_old:0.261,explained_var_new:0.332
# current self-play batch: 250
# num_playouts:1000, win: 7, lose: 3, tie:0
# batch i:251, episode_len:14
# kl:0.02206,lr_multiplier:0.296,loss:2.8171939849853516,entropy:2.1815781593322754,explained_var_old:0.291,explained_var_new:0.359
# batch i:252, episode_len:8
# kl:0.01777,lr_multiplier:0.296,loss:2.826347827911377,entropy:2.1725375652313232,explained_var_old:0.251,explained_var_new:0.336
# batch i:253, episode_len:11
# kl:0.01690,lr_multiplier:0.296,loss:2.787410259246826,entropy:2.217705726623535,explained_var_old:0.316,explained_var_new:0.396
# batch i:254, episode_len:10
# kl:0.02783,lr_multiplier:0.296,loss:2.7499544620513916,entropy:2.166140079498291,explained_var_old:0.299,explained_var_new:0.390
# batch i:255, episode_len:15
# kl:0.02858,lr_multiplier:0.296,loss:2.7963340282440186,entropy:2.180854558944702,explained_var_old:0.308,explained_var_new:0.371
# batch i:256, episode_len:11
# kl:0.03776,lr_multiplier:0.296,loss:2.809255838394165,entropy:2.080986499786377,explained_var_old:0.261,explained_var_new:0.347
# batch i:257, episode_len:16
# kl:0.03498,lr_multiplier:0.296,loss:2.822026491165161,entropy:2.1685791015625,explained_var_old:0.286,explained_var_new:0.349
# batch i:258, episode_len:10
# kl:0.02436,lr_multiplier:0.296,loss:2.722548246383667,entropy:2.1018919944763184,explained_var_old:0.309,explained_var_new:0.363
# batch i:259, episode_len:9
# kl:0.02547,lr_multiplier:0.296,loss:2.7954373359680176,entropy:2.228273391723633,explained_var_old:0.300,explained_var_new:0.375
# batch i:260, episode_len:7
# kl:0.02412,lr_multiplier:0.296,loss:2.705775022506714,entropy:2.1047873497009277,explained_var_old:0.284,explained_var_new:0.355
# batch i:261, episode_len:7
# kl:0.02267,lr_multiplier:0.296,loss:2.702289342880249,entropy:2.0788257122039795,explained_var_old:0.316,explained_var_new:0.372
# batch i:262, episode_len:10
# kl:0.02596,lr_multiplier:0.296,loss:2.776826858520508,entropy:2.1469390392303467,explained_var_old:0.298,explained_var_new:0.366
# batch i:263, episode_len:9
# kl:0.02144,lr_multiplier:0.296,loss:2.7173662185668945,entropy:2.121511220932007,explained_var_old:0.324,explained_var_new:0.394
# batch i:264, episode_len:10
# kl:0.02889,lr_multiplier:0.296,loss:2.761590003967285,entropy:2.1245436668395996,explained_var_old:0.335,explained_var_new:0.409
# batch i:265, episode_len:13
# kl:0.04118,lr_multiplier:0.198,loss:2.723532199859619,entropy:2.146169662475586,explained_var_old:0.314,explained_var_new:0.381
# batch i:266, episode_len:10
# kl:0.02775,lr_multiplier:0.198,loss:2.684473991394043,entropy:2.0542404651641846,explained_var_old:0.342,explained_var_new:0.386
# batch i:267, episode_len:7
# kl:0.01965,lr_multiplier:0.198,loss:2.6608424186706543,entropy:2.0805182456970215,explained_var_old:0.287,explained_var_new:0.356
# batch i:268, episode_len:11
# kl:0.01886,lr_multiplier:0.198,loss:2.691272258758545,entropy:2.1649999618530273,explained_var_old:0.362,explained_var_new:0.425
# batch i:269, episode_len:12
# kl:0.01817,lr_multiplier:0.198,loss:2.6945083141326904,entropy:2.071791887283325,explained_var_old:0.363,explained_var_new:0.398
# batch i:270, episode_len:11
# kl:0.01422,lr_multiplier:0.198,loss:2.6670432090759277,entropy:2.065481662750244,explained_var_old:0.319,explained_var_new:0.368
# batch i:271, episode_len:14
# kl:0.01661,lr_multiplier:0.198,loss:2.6280031204223633,entropy:2.046426296234131,explained_var_old:0.371,explained_var_new:0.414
# batch i:272, episode_len:7
# kl:0.01621,lr_multiplier:0.198,loss:2.586196184158325,entropy:2.028698205947876,explained_var_old:0.374,explained_var_new:0.428
# batch i:273, episode_len:7
# kl:0.01238,lr_multiplier:0.198,loss:2.692403554916382,entropy:2.0533816814422607,explained_var_old:0.306,explained_var_new:0.355
# batch i:274, episode_len:8
# kl:0.01430,lr_multiplier:0.198,loss:2.651416063308716,entropy:2.082641124725342,explained_var_old:0.366,explained_var_new:0.405
# batch i:275, episode_len:14
# kl:0.02424,lr_multiplier:0.198,loss:2.661834239959717,entropy:2.0412628650665283,explained_var_old:0.345,explained_var_new:0.405
# batch i:276, episode_len:9
# kl:0.01414,lr_multiplier:0.198,loss:2.7210638523101807,entropy:2.062830924987793,explained_var_old:0.295,explained_var_new:0.345
# batch i:277, episode_len:7
# kl:0.01353,lr_multiplier:0.198,loss:2.680826187133789,entropy:2.096644401550293,explained_var_old:0.350,explained_var_new:0.390
# batch i:278, episode_len:8
# kl:0.01474,lr_multiplier:0.198,loss:2.653855562210083,entropy:2.03702974319458,explained_var_old:0.321,explained_var_new:0.404
# batch i:279, episode_len:8
# kl:0.01703,lr_multiplier:0.198,loss:2.7052907943725586,entropy:2.0658769607543945,explained_var_old:0.306,explained_var_new:0.359
# batch i:280, episode_len:17
# kl:0.01817,lr_multiplier:0.198,loss:2.808140754699707,entropy:2.1341609954833984,explained_var_old:0.246,explained_var_new:0.314
# batch i:281, episode_len:10
# kl:0.01202,lr_multiplier:0.198,loss:2.7038028240203857,entropy:2.126471519470215,explained_var_old:0.320,explained_var_new:0.380
# batch i:282, episode_len:10
# kl:0.01320,lr_multiplier:0.198,loss:2.5450031757354736,entropy:2.0359084606170654,explained_var_old:0.405,explained_var_new:0.434
# batch i:283, episode_len:13
# kl:0.01064,lr_multiplier:0.198,loss:2.6086742877960205,entropy:2.0158262252807617,explained_var_old:0.349,explained_var_new:0.422
# batch i:284, episode_len:7
# kl:0.01816,lr_multiplier:0.198,loss:2.5687384605407715,entropy:2.052400827407837,explained_var_old:0.371,explained_var_new:0.411
# batch i:285, episode_len:12
# kl:0.02210,lr_multiplier:0.198,loss:2.626532793045044,entropy:1.9912015199661255,explained_var_old:0.326,explained_var_new:0.385
# batch i:286, episode_len:7
# kl:0.01736,lr_multiplier:0.198,loss:2.6743531227111816,entropy:2.061680793762207,explained_var_old:0.367,explained_var_new:0.422
# batch i:287, episode_len:12
# kl:0.02062,lr_multiplier:0.198,loss:2.558786153793335,entropy:1.9321765899658203,explained_var_old:0.331,explained_var_new:0.382
# batch i:288, episode_len:7
# kl:0.01086,lr_multiplier:0.198,loss:2.5029940605163574,entropy:1.88018000125885,explained_var_old:0.359,explained_var_new:0.415
# batch i:289, episode_len:7
# kl:0.02329,lr_multiplier:0.198,loss:2.5806937217712402,entropy:2.0171732902526855,explained_var_old:0.355,explained_var_new:0.393
# batch i:290, episode_len:13
# kl:0.02759,lr_multiplier:0.198,loss:2.644641399383545,entropy:1.9747827053070068,explained_var_old:0.289,explained_var_new:0.343
# batch i:291, episode_len:7
# kl:0.01813,lr_multiplier:0.198,loss:2.640126943588257,entropy:2.057762861251831,explained_var_old:0.369,explained_var_new:0.404
# batch i:292, episode_len:9
# kl:0.02358,lr_multiplier:0.198,loss:2.560016632080078,entropy:2.0259227752685547,explained_var_old:0.373,explained_var_new:0.417
# batch i:293, episode_len:9
# kl:0.02305,lr_multiplier:0.198,loss:2.5437068939208984,entropy:1.926339030265808,explained_var_old:0.357,explained_var_new:0.401
# batch i:294, episode_len:10
# kl:0.03783,lr_multiplier:0.198,loss:2.6143345832824707,entropy:2.0086917877197266,explained_var_old:0.307,explained_var_new:0.370
# batch i:295, episode_len:10
# kl:0.03154,lr_multiplier:0.198,loss:2.6672797203063965,entropy:1.9566357135772705,explained_var_old:0.262,explained_var_new:0.307
# batch i:296, episode_len:12
# kl:0.04257,lr_multiplier:0.132,loss:2.5289275646209717,entropy:1.9679759740829468,explained_var_old:0.367,explained_var_new:0.436
# batch i:297, episode_len:18
# kl:0.04217,lr_multiplier:0.088,loss:2.646474838256836,entropy:1.961052417755127,explained_var_old:0.317,explained_var_new:0.350
# batch i:298, episode_len:7
# kl:0.01731,lr_multiplier:0.088,loss:2.533442497253418,entropy:1.9252779483795166,explained_var_old:0.347,explained_var_new:0.380
# batch i:299, episode_len:7
# kl:0.00541,lr_multiplier:0.132,loss:2.6210083961486816,entropy:1.960724115371704,explained_var_old:0.334,explained_var_new:0.365
# batch i:300, episode_len:8
# kl:0.01531,lr_multiplier:0.132,loss:2.6359968185424805,entropy:1.9683821201324463,explained_var_old:0.290,explained_var_new:0.322
# current self-play batch: 300
# num_playouts:1000, win: 9, lose: 1, tie:0
# batch i:301, episode_len:11
# kl:0.01341,lr_multiplier:0.132,loss:2.5315325260162354,entropy:1.9694719314575195,explained_var_old:0.346,explained_var_new:0.377
# batch i:302, episode_len:7
# kl:0.00703,lr_multiplier:0.198,loss:2.5897555351257324,entropy:1.967415452003479,explained_var_old:0.325,explained_var_new:0.362
# batch i:303, episode_len:9
# kl:0.01648,lr_multiplier:0.198,loss:2.5145695209503174,entropy:1.987551212310791,explained_var_old:0.359,explained_var_new:0.406
# batch i:304, episode_len:15
# kl:0.01213,lr_multiplier:0.198,loss:2.531980514526367,entropy:1.920095682144165,explained_var_old:0.347,explained_var_new:0.413
# batch i:305, episode_len:9
# ...
# current self-play batch: 400
# num_playouts:2000, win: 7, lose: 3, tie:0
# 发现新的最优策略，进行策略更新
# batch i:401, episode_len:10
# kl:0.03737,lr_multiplier:0.296,loss:2.2410192489624023,entropy:1.626568078994751,explained_var_old:0.308,explained_var_new:0.381
# batch i:402, episode_len:10
# kl:0.02981,lr_multiplier:0.296,loss:2.1895878314971924,entropy:1.5782803297042847,explained_var_old:0.332,explained_var_new:0.398
# batch i:403, episode_len:11
# kl:0.02728,lr_multiplier:0.296,loss:2.2112133502960205,entropy:1.595690369606018,explained_var_old:0.305,explained_var_new:0.386
# batch i:404, episode_len:11
# kl:0.02725,lr_multiplier:0.296,loss:2.2090015411376953,entropy:1.5981730222702026,explained_var_old:0.302,explained_var_new:0.371
# batch i:405, episode_len:7
# kl:0.03147,lr_multiplier:0.296,loss:2.1404786109924316,entropy:1.5573790073394775,explained_var_old:0.324,explained_var_new:0.417
# batch i:406, episode_len:9
# kl:0.03377,lr_multiplier:0.296,loss:2.187272310256958,entropy:1.5811023712158203,explained_var_old:0.315,explained_var_new:0.393
# batch i:407, episode_len:14
# kl:0.03713,lr_multiplier:0.296,loss:2.2373921871185303,entropy:1.64435875415802,explained_var_old:0.296,explained_var_new:0.371
# batch i:408, episode_len:12
# kl:0.02924,lr_multiplier:0.296,loss:2.1483445167541504,entropy:1.589322805404663,explained_var_old:0.305,explained_var_new:0.423
# batch i:409, episode_len:9
# kl:0.03467,lr_multiplier:0.296,loss:2.1692442893981934,entropy:1.5967788696289062,explained_var_old:0.333,explained_var_new:0.366
# batch i:410, episode_len:9
# kl:0.03404,lr_multiplier:0.296,loss:2.17976713180542,entropy:1.5690805912017822,explained_var_old:0.323,explained_var_new:0.381
# batch i:411, episode_len:11
# kl:0.02328,lr_multiplier:0.296,loss:2.133273124694824,entropy:1.5700488090515137,explained_var_old:0.371,explained_var_new:0.447
# batch i:412, episode_len:11
# kl:0.03629,lr_multiplier:0.296,loss:2.1525673866271973,entropy:1.5895812511444092,explained_var_old:0.326,explained_var_new:0.407
# batch i:413, episode_len:11
# kl:0.04213,lr_multiplier:0.198,loss:2.227874755859375,entropy:1.5860211849212646,explained_var_old:0.292,explained_var_new:0.373
# batch i:414, episode_len:11
# kl:0.02369,lr_multiplier:0.198,loss:2.084336757659912,entropy:1.5075287818908691,explained_var_old:0.364,explained_var_new:0.422
# batch i:415, episode_len:9
# kl:0.02936,lr_multiplier:0.198,loss:2.1916494369506836,entropy:1.6366709470748901,explained_var_old:0.356,explained_var_new:0.434
# batch i:416, episode_len:7
# kl:0.03226,lr_multiplier:0.198,loss:2.2173004150390625,entropy:1.6282845735549927,explained_var_old:0.330,explained_var_new:0.378
# batch i:417, episode_len:11
# kl:0.03097,lr_multiplier:0.198,loss:2.1824092864990234,entropy:1.6332037448883057,explained_var_old:0.369,explained_var_new:0.429
# batch i:418, episode_len:17
# kl:0.02169,lr_multiplier:0.198,loss:2.0618157386779785,entropy:1.565187692642212,explained_var_old:0.408,explained_var_new:0.466
# batch i:419, episode_len:15
# kl:0.01613,lr_multiplier:0.198,loss:2.1423234939575195,entropy:1.586427092552185,explained_var_old:0.342,explained_var_new:0.389
# batch i:420, episode_len:12
# kl:0.02308,lr_multiplier:0.198,loss:2.16903018951416,entropy:1.5797944068908691,explained_var_old:0.314,explained_var_new:0.370
# batch i:421, episode_len:7
# kl:0.02197,lr_multiplier:0.198,loss:2.2467994689941406,entropy:1.6486716270446777,explained_var_old:0.325,explained_var_new:0.381
# batch i:422, episode_len:14
# kl:0.02202,lr_multiplier:0.198,loss:2.153425693511963,entropy:1.577042818069458,explained_var_old:0.298,explained_var_new:0.372
# batch i:423, episode_len:13
# kl:0.01398,lr_multiplier:0.198,loss:2.1623964309692383,entropy:1.5571321249008179,explained_var_old:0.359,explained_var_new:0.414
# batch i:424, episode_len:9
# kl:0.02465,lr_multiplier:0.198,loss:2.1047773361206055,entropy:1.5618867874145508,explained_var_old:0.365,explained_var_new:0.421
# batch i:425, episode_len:10
# kl:0.02610,lr_multiplier:0.198,loss:2.2319469451904297,entropy:1.5833038091659546,explained_var_old:0.305,explained_var_new:0.363
# batch i:426, episode_len:7
# kl:0.03300,lr_multiplier:0.198,loss:2.160165786743164,entropy:1.6640689373016357,explained_var_old:0.345,explained_var_new:0.394
# batch i:427, episode_len:7
# kl:0.03929,lr_multiplier:0.198,loss:2.132524013519287,entropy:1.5399181842803955,explained_var_old:0.350,explained_var_new:0.389
# batch i:428, episode_len:10
# kl:0.03166,lr_multiplier:0.198,loss:2.1963868141174316,entropy:1.5706701278686523,explained_var_old:0.317,explained_var_new:0.367
# batch i:429, episode_len:7
# kl:0.02563,lr_multiplier:0.198,loss:2.1328125,entropy:1.62080717086792,explained_var_old:0.391,explained_var_new:0.435
# batch i:430, episode_len:8
# kl:0.02254,lr_multiplier:0.198,loss:2.228891372680664,entropy:1.5597035884857178,explained_var_old:0.292,explained_var_new:0.358
# batch i:431, episode_len:10
# kl:0.03187,lr_multiplier:0.198,loss:2.0751781463623047,entropy:1.580741286277771,explained_var_old:0.361,explained_var_new:0.440
# batch i:432, episode_len:11
# kl:0.02921,lr_multiplier:0.198,loss:2.1276071071624756,entropy:1.5302555561065674,explained_var_old:0.347,explained_var_new:0.390
# batch i:433, episode_len:11
# kl:0.02563,lr_multiplier:0.198,loss:2.1278738975524902,entropy:1.5580288171768188,explained_var_old:0.370,explained_var_new:0.422
# batch i:434, episode_len:14
# kl:0.01812,lr_multiplier:0.198,loss:2.1380953788757324,entropy:1.5908229351043701,explained_var_old:0.351,explained_var_new:0.391
# batch i:435, episode_len:7
# kl:0.02638,lr_multiplier:0.198,loss:2.0777883529663086,entropy:1.5154067277908325,explained_var_old:0.370,explained_var_new:0.422
# batch i:436, episode_len:9
# kl:0.02144,lr_multiplier:0.198,loss:2.0904223918914795,entropy:1.5475578308105469,explained_var_old:0.404,explained_var_new:0.447
# batch i:437, episode_len:13
# kl:0.02089,lr_multiplier:0.198,loss:2.132014513015747,entropy:1.6118686199188232,explained_var_old:0.404,explained_var_new:0.446
# batch i:438, episode_len:9
# kl:0.01825,lr_multiplier:0.198,loss:2.060401439666748,entropy:1.550752878189087,explained_var_old:0.383,explained_var_new:0.438
# batch i:439, episode_len:9
# kl:0.01489,lr_multiplier:0.198,loss:1.983794927597046,entropy:1.50679612159729,explained_var_old:0.461,explained_var_new:0.500
# batch i:440, episode_len:7
# kl:0.01988,lr_multiplier:0.198,loss:2.1177539825439453,entropy:1.5139693021774292,explained_var_old:0.333,explained_var_new:0.380
# batch i:441, episode_len:7
# kl:0.01344,lr_multiplier:0.198,loss:2.0453553199768066,entropy:1.5448371171951294,explained_var_old:0.419,explained_var_new:0.471
# batch i:442, episode_len:9
# kl:0.01818,lr_multiplier:0.198,loss:2.0259697437286377,entropy:1.5175238847732544,explained_var_old:0.444,explained_var_new:0.480
# batch i:443, episode_len:13
# kl:0.02282,lr_multiplier:0.198,loss:2.062582492828369,entropy:1.4885437488555908,explained_var_old:0.387,explained_var_new:0.450
# batch i:444, episode_len:7
# kl:0.02791,lr_multiplier:0.198,loss:2.1075100898742676,entropy:1.5113292932510376,explained_var_old:0.337,explained_var_new:0.383
# batch i:445, episode_len:9
# kl:0.03814,lr_multiplier:0.198,loss:1.9813871383666992,entropy:1.4727983474731445,explained_var_old:0.389,explained_var_new:0.444
# batch i:446, episode_len:10
# kl:0.03430,lr_multiplier:0.198,loss:2.120906114578247,entropy:1.5408498048782349,explained_var_old:0.389,explained_var_new:0.439
# batch i:447, episode_len:13
# kl:0.01503,lr_multiplier:0.198,loss:2.1089117527008057,entropy:1.5788300037384033,explained_var_old:0.417,explained_var_new:0.448
# batch i:448, episode_len:8
# kl:0.02461,lr_multiplier:0.198,loss:2.1151647567749023,entropy:1.5253099203109741,explained_var_old:0.338,explained_var_new:0.391
# batch i:449, episode_len:13
# kl:0.02148,lr_multiplier:0.198,loss:2.136683464050293,entropy:1.596733808517456,explained_var_old:0.374,explained_var_new:0.427
# batch i:450, episode_len:12
# kl:0.01588,lr_multiplier:0.198,loss:2.0224595069885254,entropy:1.5372806787490845,explained_var_old:0.407,explained_var_new:0.453
# current self-play batch: 450
# num_playouts:2000, win: 9, lose: 1, tie:0
# 发现新的最优策略，进行策略更新
# batch i:451, episode_len:15
# kl:0.02012,lr_multiplier:0.198,loss:2.022386074066162,entropy:1.463572382926941,explained_var_old:0.406,explained_var_new:0.469
# batch i:452, episode_len:13
# kl:0.02286,lr_multiplier:0.198,loss:2.081545829772949,entropy:1.5755462646484375,explained_var_old:0.413,explained_var_new:0.458
# batch i:453, episode_len:10
# kl:0.01951,lr_multiplier:0.198,loss:1.887894630432129,entropy:1.4813321828842163,explained_var_old:0.478,explained_var_new:0.525
# batch i:454, episode_len:9
# kl:0.03185,lr_multiplier:0.198,loss:2.1216979026794434,entropy:1.5416721105575562,explained_var_old:0.400,explained_var_new:0.438
# batch i:455, episode_len:9
# kl:0.03392,lr_multiplier:0.198,loss:2.014571189880371,entropy:1.5226948261260986,explained_var_old:0.439,explained_var_new:0.502
# batch i:456, episode_len:10
# kl:0.02525,lr_multiplier:0.198,loss:2.0382795333862305,entropy:1.545348048210144,explained_var_old:0.401,explained_var_new:0.447
# batch i:457, episode_len:13
# kl:0.01689,lr_multiplier:0.198,loss:1.9797395467758179,entropy:1.4937461614608765,explained_var_old:0.466,explained_var_new:0.503
# batch i:458, episode_len:18
# kl:0.02696,lr_multiplier:0.198,loss:2.0141003131866455,entropy:1.4733338356018066,explained_var_old:0.434,explained_var_new:0.488
# batch i:459, episode_len:11
# kl:0.02931,lr_multiplier:0.198,loss:1.9489233493804932,entropy:1.4826278686523438,explained_var_old:0.429,explained_var_new:0.486
# batch i:460, episode_len:7
# kl:0.03418,lr_multiplier:0.198,loss:2.0388364791870117,entropy:1.5217905044555664,explained_var_old:0.382,explained_var_new:0.424
# batch i:461, episode_len:7
# kl:0.01758,lr_multiplier:0.198,loss:2.016692638397217,entropy:1.4885797500610352,explained_var_old:0.379,explained_var_new:0.450
# batch i:462, episode_len:9
# kl:0.03017,lr_multiplier:0.198,loss:2.0210254192352295,entropy:1.5425310134887695,explained_var_old:0.437,explained_var_new:0.473
# batch i:463, episode_len:7
# kl:0.02041,lr_multiplier:0.198,loss:1.968198299407959,entropy:1.4867419004440308,explained_var_old:0.435,explained_var_new:0.483
# batch i:464, episode_len:8
# kl:0.02564,lr_multiplier:0.198,loss:2.018369197845459,entropy:1.4885276556015015,explained_var_old:0.424,explained_var_new:0.481
# batch i:465, episode_len:9
# kl:0.02669,lr_multiplier:0.198,loss:2.0688228607177734,entropy:1.5544042587280273,explained_var_old:0.452,explained_var_new:0.502
# batch i:466, episode_len:16
# kl:0.01803,lr_multiplier:0.198,loss:2.022700071334839,entropy:1.4912569522857666,explained_var_old:0.401,explained_var_new:0.457
# batch i:467, episode_len:12
# kl:0.02689,lr_multiplier:0.198,loss:2.031461715698242,entropy:1.5350595712661743,explained_var_old:0.385,explained_var_new:0.433
# batch i:468, episode_len:7
# kl:0.02384,lr_multiplier:0.198,loss:2.040299415588379,entropy:1.4909179210662842,explained_var_old:0.367,explained_var_new:0.417
# batch i:469, episode_len:15
# kl:0.02326,lr_multiplier:0.198,loss:2.1619138717651367,entropy:1.5150854587554932,explained_var_old:0.330,explained_var_new:0.385
# batch i:470, episode_len:11
# kl:0.02071,lr_multiplier:0.198,loss:2.0084261894226074,entropy:1.4876272678375244,explained_var_old:0.390,explained_var_new:0.450
# batch i:471, episode_len:11
# kl:0.02493,lr_multiplier:0.198,loss:2.086244583129883,entropy:1.5237441062927246,explained_var_old:0.392,explained_var_new:0.455
# batch i:472, episode_len:11
# kl:0.02569,lr_multiplier:0.198,loss:2.045355796813965,entropy:1.5340412855148315,explained_var_old:0.401,explained_var_new:0.454
# batch i:473, episode_len:7
# kl:0.02356,lr_multiplier:0.198,loss:2.0873889923095703,entropy:1.5166682004928589,explained_var_old:0.385,explained_var_new:0.423
# batch i:474, episode_len:11
# kl:0.02105,lr_multiplier:0.198,loss:1.9472601413726807,entropy:1.4497843980789185,explained_var_old:0.479,explained_var_new:0.517
# batch i:475, episode_len:9
# kl:0.02487,lr_multiplier:0.198,loss:1.9696054458618164,entropy:1.5010159015655518,explained_var_old:0.478,explained_var_new:0.522
# batch i:476, episode_len:9
# kl:0.01697,lr_multiplier:0.198,loss:2.0319437980651855,entropy:1.5063016414642334,explained_var_old:0.408,explained_var_new:0.457
# batch i:477, episode_len:9
# kl:0.02473,lr_multiplier:0.198,loss:2.0455830097198486,entropy:1.5538196563720703,explained_var_old:0.407,explained_var_new:0.458
# batch i:478, episode_len:13
# kl:0.03119,lr_multiplier:0.198,loss:2.0845553874969482,entropy:1.4811911582946777,explained_var_old:0.378,explained_var_new:0.434
# batch i:479, episode_len:7
# kl:0.01426,lr_multiplier:0.198,loss:2.0077157020568848,entropy:1.5227701663970947,explained_var_old:0.420,explained_var_new:0.456
# batch i:480, episode_len:12
# kl:0.01971,lr_multiplier:0.198,loss:1.9877692461013794,entropy:1.539930820465088,explained_var_old:0.491,explained_var_new:0.536
# batch i:481, episode_len:11
# kl:0.02266,lr_multiplier:0.198,loss:1.936400294303894,entropy:1.487558364868164,explained_var_old:0.489,explained_var_new:0.537
# batch i:482, episode_len:10
# kl:0.02338,lr_multiplier:0.198,loss:2.0596539974212646,entropy:1.5491695404052734,explained_var_old:0.410,explained_var_new:0.453
# batch i:483, episode_len:11
# kl:0.01549,lr_multiplier:0.198,loss:2.0481786727905273,entropy:1.5041033029556274,explained_var_old:0.404,explained_var_new:0.466
# batch i:484, episode_len:10
# kl:0.02492,lr_multiplier:0.198,loss:1.9240093231201172,entropy:1.4542951583862305,explained_var_old:0.462,explained_var_new:0.496
# batch i:485, episode_len:8
# kl:0.01510,lr_multiplier:0.198,loss:2.040435314178467,entropy:1.53947913646698,explained_var_old:0.409,explained_var_new:0.477
# batch i:486, episode_len:12
# kl:0.02531,lr_multiplier:0.198,loss:2.0406575202941895,entropy:1.5287030935287476,explained_var_old:0.435,explained_var_new:0.486
# batch i:487, episode_len:10
# kl:0.02565,lr_multiplier:0.198,loss:1.9781330823898315,entropy:1.5190460681915283,explained_var_old:0.475,explained_var_new:0.519
# batch i:488, episode_len:15
# kl:0.02049,lr_multiplier:0.198,loss:1.9368869066238403,entropy:1.4482841491699219,explained_var_old:0.391,explained_var_new:0.454
# batch i:489, episode_len:8
# kl:0.02143,lr_multiplier:0.198,loss:1.9751369953155518,entropy:1.498996615409851,explained_var_old:0.452,explained_var_new:0.483
# batch i:490, episode_len:11
# kl:0.02499,lr_multiplier:0.198,loss:1.9549099206924438,entropy:1.4200565814971924,explained_var_old:0.376,explained_var_new:0.451
# batch i:491, episode_len:8
# kl:0.02144,lr_multiplier:0.198,loss:1.9619174003601074,entropy:1.4932950735092163,explained_var_old:0.481,explained_var_new:0.508
# batch i:492, episode_len:11
# kl:0.02310,lr_multiplier:0.198,loss:2.011556386947632,entropy:1.513329267501831,explained_var_old:0.476,explained_var_new:0.519
# batch i:493, episode_len:9
# kl:0.01881,lr_multiplier:0.198,loss:1.999793291091919,entropy:1.5191737413406372,explained_var_old:0.486,explained_var_new:0.526
# batch i:494, episode_len:22
# kl:0.02173,lr_multiplier:0.198,loss:1.9945664405822754,entropy:1.5023093223571777,explained_var_old:0.377,explained_var_new:0.439
# batch i:495, episode_len:13
# kl:0.02451,lr_multiplier:0.198,loss:1.9209785461425781,entropy:1.4111237525939941,explained_var_old:0.432,explained_var_new:0.472
# batch i:496, episode_len:11
# kl:0.03186,lr_multiplier:0.198,loss:1.8887593746185303,entropy:1.4478731155395508,explained_var_old:0.462,explained_var_new:0.532
# batch i:497, episode_len:7
# kl:0.02035,lr_multiplier:0.198,loss:1.9461991786956787,entropy:1.413661241531372,explained_var_old:0.424,explained_var_new:0.473
# batch i:498, episode_len:7
# kl:0.03174,lr_multiplier:0.198,loss:1.8511009216308594,entropy:1.4331333637237549,explained_var_old:0.488,explained_var_new:0.542
# batch i:499, episode_len:13
# kl:0.02127,lr_multiplier:0.198,loss:2.0376851558685303,entropy:1.5185487270355225,explained_var_old:0.458,explained_var_new:0.505
# batch i:500, episode_len:10
# kl:0.02677,lr_multiplier:0.198,loss:1.9344241619110107,entropy:1.4101144075393677,explained_var_old:0.435,explained_var_new:0.498
# current self-play batch: 500
# num_playouts:2000, win: 9, lose: 1, tie:0
